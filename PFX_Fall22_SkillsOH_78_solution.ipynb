# %% [markdown]
# <a href="https://colab.research.google.com/github/Balonglongz/github-codespaces-demo/blob/main/PFX_Fall22_SkillsOH_78_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `Final Exam`, `Fall 2022`: `Time Series Analysis of US Inflation`
# _Version 1.0.1_
#
# Change history:
# 1.0.1 - bugfix ex2 test code.
# 1.0 - initial release
#
# *All of the header information is important. Please read it..*
#
# **Topics, number of exercises:** This problem builds on your knowledge of Pandas, Numpy, basic Python data structures, and implementing mathematical functions. It has **9** exercises, numbered 0 to **8**. There are **18** available points. However, to earn 100% the threshold is **13** points. (Therefore, once you hit **13** points, you can stop. There is no extra credit for exceeding this threshold.)
#
# **Exercise ordering:** Each exercise builds logically on previous exercises, but you may solve them in any order. That is, if you can't solve an exercise, you can still move on and try the next one. Use this to your advantage, as the exercises are **not** necessarily ordered in terms of difficulty. Higher point values generally indicate more difficult exercises.
#
# **Demo cells:** Code cells starting with the comment `### define demo inputs` load results from prior exercises applied to the entire data set and use those to build demo inputs. These must be run for subsequent demos to work properly, but they do not affect the test cells. The data loaded in these cells may be rather large (at least in terms of human readability). You are free to print or otherwise use Python to explore them, but we did not print them in the starter code.
#
# **Debugging your code:** Right before each exercise test cell, there is a block of text explaining the variables available to you for debugging. You may use these to test your code and can print/display them as needed (careful when printing large objects, you may want to print the head or chunks of rows at a time).
#
# **Exercise point breakdown:**
#
# - Exercise 0: **1** point(s)
# - Exercise 1: **1** point(s)
# - Exercise 2: **2** point(s)
# - Exercise 3: **2** point(s)
# - Exercise 4: **2** point(s)
# - Exercise 5: **2** point(s)
# - Exercise 6: **2** point(s)
# - Exercise 7: **3** point(s)
# - Exercise 8: **3** point(s)
#
# **Final reminders:**
#
# - Submit after **every exercise**
# - Review the generated grade report after you submit to see what errors were returned
# - Stay calm, skip problems as needed, and take short breaks at your leisure

# %% [markdown]
# ## Background Inflation
#
# Inflation is an increase in overall prices in an economy over time. Deflation is "negative inflation", a decrease in prices over time. A common way to measure inflation is to first calculate the CPI (price of a representative basket of goods), then compute the difference in CPI over a time interval. In other words if the CPI is 100 at one point in time, and the CPI is 105 one year later then we would say that the inflation rate over that year was 5%.
#
# ## Data
#
# We have obtained the US CPI for each month going back to the early 20th century from The Organisation for Economic Co-operation and Development.
#
# ## Analysis goals
# - Use the CPI data to calculate the inflation rate at any point in history over an arbitrary number of months.
# - Attempt to predict the inflation rate in future months based on the inflation rate in previous months using exponential smoothing models.
#     - Evaluate how "good" the predictions are.
#     - Tune the models to pick the best parameters.
#     - Make inferences based on the selected parameters.

# %%
# uncomment in Google Colab
# !python --version
# !pip install dill
import dill as pickle
# !pip install cryptography
# Out:
# Collecting dill
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.7
# Requirement already satisfied: cryptography in /usr/local/lib/python3.10/dist-packages (41.0.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography) (2.21)

# %%
### Global Imports
import pandas as pd
import numpy as np
import pickle

# Some functionality needed by the notebook and demo cells:
from pprint import pprint, pformat
import math

# === Messages === #

def status_msg(s, verbose=True, **kwargs):
    if verbose:
        print(s, **kwargs)

# === Input/output === #

# def load_df_from_file(basename, dirname='resource/asnlib/publicdata/', abort_on_error=False, verbose=False):
def load_df_from_file(basename, dirname='', abort_on_error=False, verbose=False):
    from os.path import isfile
    from dill import loads
    from pandas import DataFrame
    df = DataFrame()
    filename = f"{dirname}{basename}"
    status_msg(f"Loading `DataFrame` from '{filename}'...", verbose=verbose)
    if isfile(filename):
        try:
            with open(filename, "rb") as fp:
                df = loads(fp.read())
            status_msg(f"  ==> Done!", verbose=verbose)
        except:
            if abort_on_error:
                raise
            else:
                df = DataFrame()
                status_msg(f"  ==> An error occurred.", verbose=verbose)
    return df

# def load_obj_from_file(basename, dirname='resource/asnlib/publicdata/', abort_on_error=False, verbose=False):
def load_obj_from_file(basename, dirname='', abort_on_error=False, verbose=False):
    from os.path import isfile
    from dill import loads
    from pandas import DataFrame
    filename = f"{dirname}{basename}"
    status_msg(f"Loading object from '{filename}'...", verbose=verbose)
    if isfile(filename):
        try:
            with open(filename, "rb") as fp:
                df = loads(fp.read())
            status_msg(f"  ==> Done! Type: `{type(df)}`", verbose=verbose)
        except:
            if abort_on_error:
                raise
            else:
                df = DataFrame()
                status_msg(f"  ==> An error occurred.", verbose=verbose)
    else:
        df = None
    return df

# %%
# import files
# !wget https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tc_7
# !wget https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tc_8
# !wget https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/cpi_urban_all.csv

# !mkdir tester_fw
# %cd tester_fw

# !wget https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tester_fw/__init__.py
# !wget https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tester_fw/test_utils.py
# !wget https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tester_fw/testers.py

# %cd ..
# Out:
# --2023-11-22 14:56:28--  https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tc_7
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54500 (53K) [text/plain]
# Saving to: ‘tc_7’
#
# tc_7                100%[===================>]  53.22K  --.-KB/s    in 0.01s
#
# 2023-11-22 14:56:28 (4.00 MB/s) - ‘tc_7’ saved [54500/54500]
#
# --2023-11-22 14:56:28--  https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tc_8
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 909880 (889K) [text/plain]
# Saving to: ‘tc_8’
#
# tc_8                100%[===================>] 888.55K  --.-KB/s    in 0.06s
#
# 2023-11-22 14:56:28 (15.2 MB/s) - ‘tc_8’ saved [909880/909880]
#
# --2023-11-22 14:56:28--  https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/cpi_urban_all.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8855 (8.6K) [text/plain]
# Saving to: ‘cpi_urban_all.csv’
#
# cpi_urban_all.csv   100%[===================>]   8.65K  --.-KB/s    in 0s
#
# 2023-11-22 14:56:29 (84.9 MB/s) - ‘cpi_urban_all.csv’ saved [8855/8855]
#
# /content/tester_fw
# --2023-11-22 14:56:29--  https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tester_fw/__init__.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4701 (4.6K) [text/plain]
# Saving to: ‘__init__.py’
#
# __init__.py         100%[===================>]   4.59K  --.-KB/s    in 0s
#
# 2023-11-22 14:56:29 (56.4 MB/s) - ‘__init__.py’ saved [4701/4701]
#
# --2023-11-22 14:56:29--  https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tester_fw/test_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3997 (3.9K) [text/plain]
# Saving to: ‘test_utils.py’
#
# test_utils.py       100%[===================>]   3.90K  --.-KB/s    in 0s
#
# 2023-11-22 14:56:29 (53.0 MB/s) - ‘test_utils.py’ saved [3997/3997]
#
# --2023-11-22 14:56:29--  https://raw.githubusercontent.com/gt-cse-6040/topic_12_FEX_FA22_78/main/tester_fw/testers.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4470 (4.4K) [text/plain]
# Saving to: ‘testers.py’
#
# testers.py          100%[===================>]   4.37K  --.-KB/s    in 0s
#
# 2023-11-22 14:56:29 (37.3 MB/s) - ‘testers.py’ saved [4470/4470]
#
# /content

# %% [markdown]
# ## Exercise 0 - (**1** Points):
# To start things off we will load the CPI data into the notebook environment. You do not need to modify the cell below, just execute the test and collect your free point!
#
# This cell will also display the first few rows and last few rows of the CPI data we just loaded.

# %%
cpi_all_df = pd.read_csv('cpi_urban_all.csv')
display(cpi_all_df.head())
display(cpi_all_df.tail())

# %% [markdown]
# <!-- Test Cell Boilerplate -->
# The cell below will test your solution for Exercise 0. The testing variables will be available for debugging under the following names in a dictionary format.
# - `input_vars` - Input variables for your solution.
# - `original_input_vars` - Copy of input variables from prior to running your solution. These _should_ be the same as `input_vars` - otherwise the inputs were modified by your solution.
# - `returned_output_vars` - Outputs returned by your solution.
# - `true_output_vars` - The expected output. This _should_ "match" `returned_output_vars` based on the question requirements - otherwise, your solution is not returning the correct output.

# %%
### test_cell_ex0
assert 'cpi_all_df' in globals()
assert isinstance(cpi_all_df, pd.DataFrame)
print('Passed! Please submit.')

# %% [markdown]
# ## Grid search
#
# Calculus won't work for finding the optimal parameters for either flavor of exponential smoothing implemented above. A "brute-force" alternative is to generate a list of suitable candidates for each parameter and test our functions on all possible combinations. This is called a grid search. It's not flashy, but for a lot of modeling techniques it's one of the only suitable choices.

# %% [markdown]
# ## Exercise 7 - (**3** Points):
# Define the function `build_grid(params)`. The input `params` will be a dictionary mapping strings to arrays (or array-like data structures such as `list`s). Consider each string a parameter name and each value in the corresponding array to be a candidate value for that parameter.
#
# Your function should return a list of dictionaries which satisfies the following:
# - Each dictionary maps each parameter name to exactly one candidate value for that parameter.
# - Exactly one dictionary exists for each combination of parameters.
# - The list is sorted by the values associated with each key. The sort priority for each key should be based on their lexographical order.
#
# For example, `build_params({'b': [1, 2], 'z': [3, 5, 6], 'a': [100, 10]})` should return:
# ```
# [{'b': 1, 'z': 3, 'a': 10},
#  {'b': 1, 'z': 5, 'a': 10},
#  {'b': 1, 'z': 6, 'a': 10},
#  {'b': 2, 'z': 3, 'a': 10},
#  {'b': 2, 'z': 5, 'a': 10},
#  {'b': 2, 'z': 6, 'a': 10},
#  {'b': 1, 'z': 3, 'a': 100},
#  {'b': 1, 'z': 5, 'a': 100},
#  {'b': 1, 'z': 6, 'a': 100},
#  {'b': 2, 'z': 3, 'a': 100},
#  {'b': 2, 'z': 5, 'a': 100},
#  {'b': 2, 'z': 6, 'a': 100}]
# ```
#
# Notice the following:
# - There are 3 parameters. The length of the lists assigned to the parameters are 2, 3, and 2.
#     - Thus there are 12 (`2*3*2`)possible combinations.
# - Each possible combination is represented exactly once in the list.
# - The list is sorted first by the `'a'` value, then by the `'b'` value, and finally by the `'z'` value.
#
# Keep in mind that the function needs to work for an **arbitrary** dictionary (the number of keys, the keys themselves, and the values can be **anything** which meets the which has the structure given earlier in the prompt).
#
# **Note**: You may find the functions `itertools.product` or `numpy.meshgrid` helpful in solving this problem.

# %%
### Define demo inputs

demo_params_ex7 = {'b': [1, 2], 'z': [3, 5, 6], 'a': [100, 10]}

# %%
from itertools import product

def build_grid(params):
    # Extract keys and sort them lexicographically
    keys = sorted(params.keys())
    print("Sorted keys:", keys)

    # Prepare the lists for itertools.product
    lists_for_product = [params[key] for key in keys]
    print("Lists for itertools.product:", lists_for_product)

    # Generate all combinations of parameter values
    combinations = product(*lists_for_product)
    combinations_list = list(combinations)  # Convert generator to a list to print
    print("Generated combinations:", combinations_list)

    # Build a list of dictionaries for each combination
    grid = [dict(zip(keys, combo)) for combo in combinations_list]
    print("Grid of dictionaries before sorting:", grid)

    # Sort the grid based on values of each dictionary
    grid.sort(key=lambda x: [x[key] for key in keys])
    print("Final sorted grid:", grid)
    return grid

### demo function call
build_grid(demo_params_ex7)
# Out:
# Sorted keys: ['a', 'b', 'z']
# Lists for itertools.product: [[100, 10], [1, 2], [3, 5, 6]]
# Generated combinations: [(100, 1, 3), (100, 1, 5), (100, 1, 6), (100, 2, 3), (100, 2, 5), (100, 2, 6), (10, 1, 3), (10, 1, 5), (10, 1, 6), (10, 2, 3), (10, 2, 5), (10, 2, 6)]
# Grid of dictionaries before sorting: [{'a': 100, 'b': 1, 'z': 3}, {'a': 100, 'b': 1, 'z': 5}, {'a': 100, 'b': 1, 'z': 6}, {'a': 100, 'b': 2, 'z': 3}, {'a': 100, 'b': 2, 'z': 5}, {'a': 100, 'b': 2, 'z': 6}, {'a': 10, 'b': 1, 'z': 3}, {'a': 10, 'b': 1, 'z': 5}, {'a': 10, 'b': 1, 'z': 6}, {'a': 10, 'b': 2, 'z': 3}, {'a': 10, 'b': 2, 'z': 5}, {'a': 10, 'b': 2, 'z': 6}]
# Final sorted grid: [{'a': 10, 'b': 1, 'z': 3}, {'a': 10, 'b': 1, 'z': 5}, {'a': 10, 'b': 1, 'z': 6}, {'a': 10, 'b': 2, 'z': 3}, {'a': 10, 'b': 2, 'z': 5}, {'a': 10, 'b': 2, 'z': 6}, {'a': 100, 'b': 1, 'z': 3}, {'a': 100, 'b': 1, 'z': 5}, {'a': 100, 'b': 1, 'z': 6}, {'a': 100, 'b': 2, 'z': 3}, {'a': 100, 'b': 2, 'z': 5}, {'a': 100, 'b': 2, 'z': 6}]
# [{'a': 10, 'b': 1, 'z': 3},
#  {'a': 10, 'b': 1, 'z': 5},
#  {'a': 10, 'b': 1, 'z': 6},
#  {'a': 10, 'b': 2, 'z': 3},
#  {'a': 10, 'b': 2, 'z': 5},
#  {'a': 10, 'b': 2, 'z': 6},
#  {'a': 100, 'b': 1, 'z': 3},
#  {'a': 100, 'b': 1, 'z': 5},
#  {'a': 100, 'b': 1, 'z': 6},
#  {'a': 100, 'b': 2, 'z': 3},
#  {'a': 100, 'b': 2, 'z': 5},
#  {'a': 100, 'b': 2, 'z': 6}]

# %%
### Exercise 7 solution
def build_grid(params):
    ### BEGIN SOLUTION
    keys = sorted(params.keys())
    grid = np.meshgrid(*params.values())
    grid = [ar.reshape(np.prod(ar.shape),1) for ar in grid]
    grid_arr = np.concatenate(grid, axis=1)
    param_dicts = [{k: row[i] for i, k in enumerate(params.keys())} for row in grid_arr]
    return sorted(param_dicts, key=lambda d: tuple(d[k] for k in keys))
    ### END SOLUTION

### demo function call
build_grid(demo_params_ex7)
# Out:
# [{'b': 1, 'z': 3, 'a': 10},
#  {'b': 1, 'z': 5, 'a': 10},
#  {'b': 1, 'z': 6, 'a': 10},
#  {'b': 2, 'z': 3, 'a': 10},
#  {'b': 2, 'z': 5, 'a': 10},
#  {'b': 2, 'z': 6, 'a': 10},
#  {'b': 1, 'z': 3, 'a': 100},
#  {'b': 1, 'z': 5, 'a': 100},
#  {'b': 1, 'z': 6, 'a': 100},
#  {'b': 2, 'z': 3, 'a': 100},
#  {'b': 2, 'z': 5, 'a': 100},
#  {'b': 2, 'z': 6, 'a': 100}]

# %% [markdown]
# <!-- Test Cell Boilerplate -->
# The cell below will test your solution for Exercise 7. The testing variables will be available for debugging under the following names in a dictionary format.
# - `input_vars` - Input variables for your solution.
# - `original_input_vars` - Copy of input variables from prior to running your solution. These _should_ be the same as `input_vars` - otherwise the inputs were modified by your solution.
# - `returned_output_vars` - Outputs returned by your solution.
# - `true_output_vars` - The expected output. This _should_ "match" `returned_output_vars` based on the question requirements - otherwise, your solution is not returning the correct output.

# %%
### test_cell_ex7
from tester_fw.testers import Tester

conf = {
    'case_file':'tc_7',
    'func': build_grid, # replace this with the function defined above
    'inputs':{ # input config dict. keys are parameter names
        'params':{
            'dtype':'dict', # data type of param.
            'check_modified':False,
        }
    },
    'outputs':{
        'output_0':{
            'index':0,
            'dtype':'',
            'check_dtype': True,
            'check_col_dtypes': True, # Ignored if dtype is not df
            'check_col_order': True, # Ignored if dtype is not df
            'check_row_order': True, # Ignored if dtype is not df
            'check_column_type': True, # Ignored if dtype is not df
            'float_tolerance': 10 ** (-6)
        }
    }
}
tester = Tester(conf, key=b'z0BNF11iKYQicR63590bVXZGa19YGvJcmzrbP6R7oAY=', path='')
for _ in range(70):
    try:
        tester.run_test()
        (input_vars, original_input_vars, returned_output_vars, true_output_vars) = tester.get_test_vars()
    except:
        (input_vars, original_input_vars, returned_output_vars, true_output_vars) = tester.get_test_vars()
        raise

print('Passed! Please submit.')
# Out:
# Passed! Please submit.

# %% [markdown]
# ## A metric to compare models
# In order to implement a grid search we need some metric of evaluating how well each model fits the data. We have provided `mse` to calculate the mean squared error for the predictions coming from a model. It takes two 1-D array arguments, `obs` (observed values) and `preds` (predicted values). It returns the mean of the squared difference between observations and predictions. A lower output from `mse` indicates that the model is a better fit.

# %%
def mse(obs, preds):
    r = obs-preds
    return np.power(r,2).mean()

# %% [markdown]
# ## Exercise 8 - (**3** Points):
# Now that we have built our parameter grid, it's time to test it.
#
# Define the function `grid_search(func, ts, grid, n_back)`. The inputs are as follows.
# - `func`: an _arbitrary_ function similar to the ones which we defined in exercises 5 and 6. It takes a 1-D time-series array and some additional parameters as inputs. It returns predictions for the time series based on some logic of which we are unaware.
#     - You can consider `func(...)[i]` to be the prediction that corresponds with `ts[i]`.
#     - `func(...)[-1]` is the prediction for the next value of `ts` which has not been observed yet.
# - `ts`: a 1-D numerical array which is a suitable input for `func`. Think of this as time-series data that we want to fit some model defined by `func`.
# - `grid`: a list of dictionaries. Each dictionary maps the remaining parameters for `func` to values. You can assume that the keys in these dictionaries match the remaining named parameters for `func`.
# - `n_back`: a positive integer smaller than `ts.shape[0]`.
#
# Your function should iteratively search the parameter sets given in `grid` to determine the set which results in the best model (the one with the lowest `mse`) given `func` and `ts`. Since exponential smoothing takes time to ramp up, you should only consider the last `n_back` **observations** in `mse` calculations. If there are multiple parameter sets which result in the same `mse` the parameter set encountered _first_ in `grid` should be chosen.
#
# You can follow this whiteboard-level algorithm to implement your search.
# 1. Initialize a variable to track the lowest `mse` returned so far in the search.
# 2. Initialize a variable to track the best set of parameters tested so far.
# 3. Iterate through each `dict` (we will call the dict `params`) in `grid`.
#     - Calculate the predictions for this set of parameters.
#         - `func(ts, **params)` will calculate the predictions.
#     - Slice the predictions and observations so that only data points corresponding to the last `n_back` **observations** are in the slices.
#     - Calculate the `mse` of the slices.
#     - Update the tracking variables set in steps 1 and 3 if the `mse` has improved.
# 4. Once all `dict`s in `grid` have been checked, return the best set of parameters.

# %%
### Define demo inputs
def demo_func_ex8(ts, a, b):
    return np.concatenate(( np.array([np.nan]),
                            ((5*a)/(7*b))*ts[1:],
                            np.array([50.])))
demo_ts_ex8 = np.array([51.1, 61.7, 34.92, 7.97, 84.03, 29.65, 85.86, 95.4, 82., 36.61])
demo_grid_ex8 = [   {'a': 2, 'b': 5},
                    {'a': 2, 'b': 11},
                    {'a': 3, 'b': 5},
                    {'a': 3, 'b': 11},
                    {'a': 21, 'b': 15},
                    {'a': 7, 'b': 11},
                    {'a': 14, 'b': 10}]
demo_n_back_ex8 = 9

# %% [markdown]
# <!-- Expected demo output text block -->
# The demo included in the solution cell below should display the following output:
# ```
# {'a': 21, 'b': 15}
# ```
# Notice:
# - `func` will return "predictions" $\hat{x}_t = \frac{5a}{7b}x_t$ whenever $0 < t \le 9$.
# - Due to the `n_back` parameter we are only looking at the last 9 observations (same interval as in the above point).
# - When $a=7k$ and $b=5k$ with any number $k$, the fraction cancels and we have $\hat{x}_t = x_t$. This will have MSE of 0.
#     - Both `{'a': 21, 'b': 15}` and `{'a': 14, 'b': 10}` match this form, so we choose `{'a': 21, 'b': 15}` which appeared first in `grid`.

# %%
import numpy as np

def mse(obs, preds):
    r = obs - preds
    return np.power(r, 2).mean()

def grid_search(func, ts, grid, n_back):
    min_mse = np.inf
    best_params = {}

    for params in grid:
        # Generate predictions using the current parameters
        preds = func(ts, **params)

        # Select only the relevant predictions for comparison
        preds = preds[-(n_back+1):-1]
        obs = ts[-n_back:]

        # Calculate the mean squared error
        cur_mse = mse(obs, preds)

        print(f"Testing parameters {params} gives MSE: {cur_mse}")

        # Update the best parameters if the current MSE is lower
        if cur_mse < min_mse:
            min_mse = cur_mse
            best_params = params
            print(f"New best parameters found: {params} with MSE: {cur_mse}")

    print(f"Best parameters after search: {best_params}")
    return best_params

### demo function call
grid_search(func=demo_func_ex8, ts=demo_ts_ex8, grid=demo_grid_ex8, n_back=9)
# Out:
# Testing parameters {'a': 2, 'b': 5} gives MSE: 2129.669637188208
# New best parameters found: {'a': 2, 'b': 5} with MSE: 2129.669637188208
# Testing parameters {'a': 2, 'b': 11} gives MSE: 3160.359339285246
# Testing parameters {'a': 3, 'b': 5} gives MSE: 1362.9885678004537
# New best parameters found: {'a': 3, 'b': 5} with MSE: 1362.9885678004537
# Testing parameters {'a': 3, 'b': 11} gives MSE: 2706.2644910252807
# Testing parameters {'a': 21, 'b': 15} gives MSE: 0.0
# New best parameters found: {'a': 21, 'b': 15} with MSE: 0.0
# Testing parameters {'a': 7, 'b': 11} gives MSE: 1241.8966082644629
# Testing parameters {'a': 14, 'b': 10} gives MSE: 0.0
# Best parameters after search: {'a': 21, 'b': 15}
# {'a': 21, 'b': 15}

# %%
### Exercise 8 solution
def grid_search(func, ts, grid, n_back):
    ### BEGIN SOLUTION
    min_mse = np.inf
    best_params = {}
    for params in grid:
        preds = func(ts, **params)
        preds = preds[-(n_back+1):-1]
        obs = ts[-n_back:]
        cur_mse = mse(obs, preds)
        if cur_mse < min_mse:
            min_mse = cur_mse
            best_params = params
    return best_params
    ### END SOLUTION

### demo function call
grid_search(func=demo_func_ex8, ts=demo_ts_ex8, grid=demo_grid_ex8, n_back=9)

# %% [markdown]
# <!-- Test Cell Boilerplate -->
# The cell below will test your solution for Exercise 8. The testing variables will be available for debugging under the following names in a dictionary format.
# - `input_vars` - Input variables for your solution.
# - `original_input_vars` - Copy of input variables from prior to running your solution. These _should_ be the same as `input_vars` - otherwise the inputs were modified by your solution.
# - `returned_output_vars` - Outputs returned by your solution.
# - `true_output_vars` - The expected output. This _should_ "match" `returned_output_vars` based on the question requirements - otherwise, your solution is not returning the correct output.

# %%
### test_cell_ex8
from tester_fw.testers import Tester

conf = {
    'case_file':'tc_8',
    'func': grid_search, # replace this with the function defined above
    'inputs':{ # input config dict. keys are parameter names
        'func':{
            'dtype':'function', # data type of param.
            'check_modified':False,
        },
        'ts':{
            'dtype':'np.ndarray', # data type of param.
            'check_modified':True,
        },
        'grid':{
            'dtype':'dict', # data type of param.
            'check_modified':True,
        },
        'n_back':{
            'dtype':'int', # data type of param.
            'check_modified':False,
        }
    },
    'outputs':{
        'output_0':{
            'index':0,
            'dtype':'dict',
            'check_dtype': True,
            'check_col_dtypes': True, # Ignored if dtype is not df
            'check_col_order': True, # Ignored if dtype is not df
            'check_row_order': True, # Ignored if dtype is not df
            'check_column_type': True, # Ignored if dtype is not df
            'float_tolerance': 10 ** (-6)
        }
    }
}
tester = Tester(conf, key=b'z0BNF11iKYQicR63590bVXZGa19YGvJcmzrbP6R7oAY=', path='')
for _ in range(70):
    try:
        tester.run_test()
        (input_vars, original_input_vars, returned_output_vars, true_output_vars) = tester.get_test_vars()
    except:
        (input_vars, original_input_vars, returned_output_vars, true_output_vars) = tester.get_test_vars()
        raise

print('Passed! Please submit.')
# Out:
# Streaming output truncated to the last 5000 lines.
# Testing parameters {'param0': 47, 'param1': 19, 'param2': 29} gives MSE: 14877.047039535591
# Testing parameters {'param0': 47, 'param1': 19, 'param2': 37} gives MSE: 14893.489153602583
# Testing parameters {'param0': 47, 'param1': 19, 'param2': 53} gives MSE: 14911.492816844077
# Testing parameters {'param0': 47, 'param1': 19, 'param2': 61} gives MSE: 14916.955093446812
# Testing parameters {'param0': 47, 'param1': 23, 'param2': 2} gives MSE: 14054.143653406934
# Testing parameters {'param0': 47, 'param1': 23, 'param2': 5} gives MSE: 14590.21380466669
# Testing parameters {'param0': 47, 'param1': 23, 'param2': 29} gives MSE: 14890.271503700467
# Testing parameters {'param0': 47, 'param1': 23, 'param2': 37} gives MSE: 14903.8595012583
# Testing parameters {'param0': 47, 'param1': 23, 'param2': 53} gives MSE: 14918.736486867823
# Testing parameters {'param0': 47, 'param1': 23, 'param2': 61} gives MSE: 14923.249826226898
# Testing parameters {'param0': 47, 'param1': 31, 'param2': 2} gives MSE: 14283.481808550756
# Testing parameters {'param0': 47, 'param1': 31, 'param2': 5} gives MSE: 14683.452490117717
# Testing parameters {'param0': 47, 'param1': 31, 'param2': 29} gives MSE: 14906.49015204991
# Testing parameters {'param0': 47, 'param1': 31, 'param2': 37} gives MSE: 14916.576463983218
# Testing parameters {'param0': 47, 'param1': 31, 'param2': 53} gives MSE: 14927.618223922818
# Testing parameters {'param0': 47, 'param1': 31, 'param2': 61} gives MSE: 14930.967761753913
# Testing parameters {'param0': 47, 'param1': 43, 'param2': 2} gives MSE: 14468.827669980978
# Testing parameters {'param0': 47, 'param1': 43, 'param2': 5} gives MSE: 14758.47499147368
# Testing parameters {'param0': 47, 'param1': 43, 'param2': 29} gives MSE: 14919.509171359448
# Testing parameters {'param0': 47, 'param1': 43, 'param2': 37} gives MSE: 14926.783529584241
# Testing parameters {'param0': 47, 'param1': 43, 'param2': 53} gives MSE: 14934.746179759328
# Testing parameters {'param0': 47, 'param1': 43, 'param2': 61} gives MSE: 14937.161501477973
# Testing parameters {'param0': 59, 'param1': 3, 'param2': 2} gives MSE: 9897.184411091177
# Testing parameters {'param0': 59, 'param1': 3, 'param2': 5} gives MSE: 12806.028766913443
# Testing parameters {'param0': 59, 'param1': 3, 'param2': 29} gives MSE: 14571.105109241043
# Testing parameters {'param0': 59, 'param1': 3, 'param2': 37} gives MSE: 14653.294338117888
# Testing parameters {'param0': 59, 'param1': 3, 'param2': 53} gives MSE: 14743.502150970022
# Testing parameters {'param0': 59, 'param1': 3, 'param2': 61} gives MSE: 14770.914964594069
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 2} gives MSE: 13694.134935337152
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 5} gives MSE: 14442.9114730361
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 29} gives MSE: 14864.560747887566
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 37} gives MSE: 14883.696748820063
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 53} gives MSE: 14904.652139062007
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 61} gives MSE: 14911.01037569322
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 2} gives MSE: 14085.743526280581
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 5} gives MSE: 14603.088169694307
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 29} gives MSE: 14892.513520584243
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 37} gives MSE: 14905.617545005885
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 53} gives MSE: 14919.964401881287
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 61} gives MSE: 14924.316861691565
# Testing parameters {'param0': 59, 'param1': 23, 'param2': 2} gives MSE: 14234.73825435256
# Testing parameters {'param0': 59, 'param1': 23, 'param2': 5} gives MSE: 14663.673737414647
# Testing parameters {'param0': 59, 'param1': 23, 'param2': 29} gives MSE: 14903.053260701692
# Testing parameters {'param0': 59, 'param1': 23, 'param2': 37} gives MSE: 14913.881739445156
# Testing parameters {'param0': 59, 'param1': 23, 'param2': 53} gives MSE: 14925.736279305474
# Testing parameters {'param0': 59, 'param1': 23, 'param2': 61} gives MSE: 14929.332439340888
# Testing parameters {'param0': 59, 'param1': 31, 'param2': 2} gives MSE: 14418.44631214875
# Testing parameters {'param0': 59, 'param1': 31, 'param2': 5} gives MSE: 14738.111014619948
# Testing parameters {'param0': 59, 'param1': 31, 'param2': 29} gives MSE: 14915.978028266158
# Testing parameters {'param0': 59, 'param1': 31, 'param2': 37} gives MSE: 14924.01516680253
# Testing parameters {'param0': 59, 'param1': 31, 'param2': 53} gives MSE: 14932.813006650898
# Testing parameters {'param0': 59, 'param1': 31, 'param2': 61} gives MSE: 14935.481716321223
# Testing parameters {'param0': 59, 'param1': 43, 'param2': 2} gives MSE: 14566.69159861474
# Testing parameters {'param0': 59, 'param1': 43, 'param2': 5} gives MSE: 14797.970204281202
# Testing parameters {'param0': 59, 'param1': 43, 'param2': 29} gives MSE: 14926.351950390856
# Testing parameters {'param0': 59, 'param1': 43, 'param2': 37} gives MSE: 14932.14796307376
# Testing parameters {'param0': 59, 'param1': 43, 'param2': 53} gives MSE: 14938.492058723596
# Testing parameters {'param0': 59, 'param1': 43, 'param2': 61} gives MSE: 14940.416354015566
# Best parameters after search: {'param0': 11, 'param1': 3, 'param2': 2}
# Testing parameters {'param1': 3, 'param0': 2} gives MSE: 28402663.159957718
# New best parameters found: {'param1': 3, 'param0': 2} with MSE: 28402663.159957718
# Testing parameters {'param1': 7, 'param0': 2} gives MSE: 4892114.567303564
# New best parameters found: {'param1': 7, 'param0': 2} with MSE: 4892114.567303564
# Testing parameters {'param1': 11, 'param0': 2} gives MSE: 1853838.3075113774
# New best parameters found: {'param1': 11, 'param0': 2} with MSE: 1853838.3075113774
# Testing parameters {'param1': 13, 'param0': 2} gives MSE: 1282878.916770164
# New best parameters found: {'param1': 13, 'param0': 2} with MSE: 1282878.916770164
# Testing parameters {'param1': 23, 'param0': 2} gives MSE: 342502.75190616935
# New best parameters found: {'param1': 23, 'param0': 2} with MSE: 342502.75190616935
# Testing parameters {'param1': 43, 'param0': 2} gives MSE: 64642.154892254344
# New best parameters found: {'param1': 43, 'param0': 2} with MSE: 64642.154892254344
# Testing parameters {'param1': 53, 'param0': 2} gives MSE: 33280.63873584443
# New best parameters found: {'param1': 53, 'param0': 2} with MSE: 33280.63873584443
# Testing parameters {'param1': 59, 'param0': 2} gives MSE: 22808.395362008836
# New best parameters found: {'param1': 59, 'param0': 2} with MSE: 22808.395362008836
# Testing parameters {'param1': 61, 'param0': 2} gives MSE: 20143.827545529362
# New best parameters found: {'param1': 61, 'param0': 2} with MSE: 20143.827545529362
# Testing parameters {'param1': 3, 'param0': 5} gives MSE: 4226857.982824272
# Testing parameters {'param1': 7, 'param0': 5} gives MSE: 654305.3475159315
# Testing parameters {'param1': 11, 'param0': 5} gives MSE: 219763.45672636066
# Testing parameters {'param1': 13, 'param0': 5} gives MSE: 142297.4994170072
# Testing parameters {'param1': 23, 'param0': 5} gives MSE: 25046.660278256346
# Testing parameters {'param1': 43, 'param0': 5} gives MSE: 669.0351799066028
# New best parameters found: {'param1': 43, 'param0': 5} with MSE: 669.0351799066028
# Testing parameters {'param1': 53, 'param0': 5} gives MSE: 8.189007608973638
# New best parameters found: {'param1': 53, 'param0': 5} with MSE: 8.189007608973638
# Testing parameters {'param1': 59, 'param0': 5} gives MSE: 237.892905903433
# Testing parameters {'param1': 61, 'param0': 5} gives MSE: 363.35948925432496
# Testing parameters {'param1': 3, 'param0': 17} gives MSE: 265709.35152391484
# Testing parameters {'param1': 7, 'param0': 17} gives MSE: 22109.69086275178
# Testing parameters {'param1': 11, 'param0': 17} gives MSE: 2368.1123436468033
# Testing parameters {'param1': 13, 'param0': 17} gives MSE: 472.283929080083
# Testing parameters {'param1': 23, 'param0': 17} gives MSE: 1820.6013874885982
# Testing parameters {'param1': 43, 'param0': 17} gives MSE: 6659.931542951994
# Testing parameters {'param1': 53, 'param0': 17} gives MSE: 8110.376134527615
# Testing parameters {'param1': 59, 'param0': 17} gives MSE: 8789.507211580132
# Testing parameters {'param1': 61, 'param0': 17} gives MSE: 8991.294090412428
# Testing parameters {'param1': 3, 'param0': 19} gives MSE: 200619.68736804885
# Testing parameters {'param1': 7, 'param0': 19} gives MSE: 14337.001479394925
# Testing parameters {'param1': 11, 'param0': 19} gives MSE: 914.2562926866464
# Testing parameters {'param1': 13, 'param0': 19} gives MSE: 37.704145902419285
# Testing parameters {'param1': 23, 'param0': 19} gives MSE: 2650.3159634597578
# Testing parameters {'param1': 43, 'param0': 19} gives MSE: 7451.518886802875
# Testing parameters {'param1': 53, 'param0': 19} gives MSE: 8813.832166149561
# Testing parameters {'param1': 59, 'param0': 19} gives MSE: 9445.475550923284
# Testing parameters {'param1': 61, 'param0': 19} gives MSE: 9632.492259738592
# Testing parameters {'param1': 3, 'param0': 29} gives MSE: 62436.55182513362
# Testing parameters {'param1': 7, 'param0': 29} gives MSE: 1215.6386510031432
# Testing parameters {'param1': 11, 'param0': 29} gives MSE: 565.1212737101386
# Testing parameters {'param1': 13, 'param0': 29} gives MSE: 1564.9549349637348
# Testing parameters {'param1': 23, 'param0': 29} gives MSE: 5977.081533571218
# Testing parameters {'param1': 43, 'param0': 29} gives MSE: 10027.703956064186
# Testing parameters {'param1': 53, 'param0': 29} gives MSE: 11044.205892138085
# Testing parameters {'param1': 59, 'param0': 29} gives MSE: 11504.128799485285
# Testing parameters {'param1': 61, 'param0': 29} gives MSE: 11639.082606121776
# Testing parameters {'param1': 3, 'param0': 31} gives MSE: 50894.49397868039
# Testing parameters {'param1': 7, 'param0': 31} gives MSE: 598.4110919252595
# Testing parameters {'param1': 11, 'param0': 31} gives MSE: 923.7181317964746
# Testing parameters {'param1': 13, 'param0': 31} gives MSE: 2039.5549641949667
# Testing parameters {'param1': 23, 'param0': 31} gives MSE: 6476.69085398376
# Testing parameters {'param1': 43, 'param0': 31} gives MSE: 10369.761923405747
# Testing parameters {'param1': 53, 'param0': 31} gives MSE: 11334.896923527444
# Testing parameters {'param1': 59, 'param0': 31} gives MSE: 11770.432350909476
# Testing parameters {'param1': 61, 'param0': 31} gives MSE: 11898.10433351206
# Testing parameters {'param1': 3, 'param0': 37} gives MSE: 28398.66959704565
# Testing parameters {'param1': 7, 'param0': 37} gives MSE: 0.0
# New best parameters found: {'param1': 7, 'param0': 37} with MSE: 0.0
# Testing parameters {'param1': 11, 'param0': 37} gives MSE: 2112.297738623229
# Testing parameters {'param1': 13, 'param0': 37} gives MSE: 3402.7991676933384
# Testing parameters {'param1': 23, 'param0': 37} gives MSE: 7730.450703165541
# Testing parameters {'param1': 43, 'param0': 37} gives MSE: 11196.66313480058
# Testing parameters {'param1': 53, 'param0': 37} gives MSE: 12033.2917365196
# Testing parameters {'param1': 59, 'param0': 37} gives MSE: 12408.611449901291
# Testing parameters {'param1': 61, 'param0': 37} gives MSE: 12518.386940756278
# Testing parameters {'param1': 3, 'param0': 41} gives MSE: 19529.364696124176
# Testing parameters {'param1': 7, 'param0': 41} gives MSE: 152.04522687293905
# Testing parameters {'param1': 11, 'param0': 41} gives MSE: 2895.1421712004294
# Testing parameters {'param1': 13, 'param0': 41} gives MSE: 4221.504235470702
# Testing parameters {'param1': 23, 'param0': 41} gives MSE: 8404.450810948229
# Testing parameters {'param1': 43, 'param0': 41} gives MSE: 11625.498104050108
# Testing parameters {'param1': 53, 'param0': 41} gives MSE: 12393.242166816877
# Testing parameters {'param1': 59, 'param0': 41} gives MSE: 12736.681458244486
# Testing parameters {'param1': 61, 'param0': 41} gives MSE: 12837.02404883345
# Testing parameters {'param1': 3, 'param0': 47} gives MSE: 11187.841655422804
# Testing parameters {'param1': 7, 'param0': 47} gives MSE: 723.1440311606233
# Testing parameters {'param1': 11, 'param0': 47} gives MSE: 3978.1288669566725
# Testing parameters {'param1': 13, 'param0': 47} gives MSE: 5301.801067273719
# Testing parameters {'param1': 23, 'param0': 47} gives MSE: 9236.613450864548
# Testing parameters {'param1': 43, 'param0': 47} gives MSE: 12142.264886309586
# Testing parameters {'param1': 53, 'param0': 47} gives MSE: 12825.120291536992
# Testing parameters {'param1': 59, 'param0': 47} gives MSE: 13129.594981801918
# Testing parameters {'param1': 61, 'param0': 47} gives MSE: 13218.443223757296
# Best parameters after search: {'param1': 7, 'param0': 37}
# Testing parameters {'param0': 2} gives MSE: 99085.3717182631
# New best parameters found: {'param0': 2} with MSE: 99085.3717182631
# Testing parameters {'param0': 3} gives MSE: 28184.283510972622
# New best parameters found: {'param0': 3} with MSE: 28184.283510972622
# Testing parameters {'param0': 5} gives MSE: 2536.5855159875337
# New best parameters found: {'param0': 5} with MSE: 2536.5855159875337
# Testing parameters {'param0': 7} gives MSE: 0.0
# New best parameters found: {'param0': 7} with MSE: 0.0
# Testing parameters {'param0': 11} gives MSE: 2096.351666105401
# Testing parameters {'param0': 13} gives MSE: 3377.1108940662452
# Testing parameters {'param0': 17} gives MSE: 5485.695320042247
# Testing parameters {'param0': 19} gives MSE: 6323.897408279173
# Testing parameters {'param0': 23} gives MSE: 7672.092297882903
# Testing parameters {'param0': 29} gives MSE: 9123.865857148981
# Testing parameters {'param0': 31} gives MSE: 9502.297458434055
# Testing parameters {'param0': 37} gives MSE: 10422.420399875735
# Testing parameters {'param0': 41} gives MSE: 10902.338104110615
# Testing parameters {'param0': 43} gives MSE: 11112.137739047612
# Testing parameters {'param0': 47} gives MSE: 11482.9584245701
# Testing parameters {'param0': 53} gives MSE: 11942.450498018923
# Testing parameters {'param0': 59} gives MSE: 12314.936863024805
# Testing parameters {'param0': 61} gives MSE: 12423.883641191298
# Best parameters after search: {'param0': 7}
# Testing parameters {'param0': 2} gives MSE: 2926702.4869206934
# New best parameters found: {'param0': 2} with MSE: 2926702.4869206934
# Testing parameters {'param0': 3} gives MSE: 1206188.618295009
# New best parameters found: {'param0': 3} with MSE: 1206188.618295009
# Testing parameters {'param0': 5} gives MSE: 369993.00575392466
# New best parameters found: {'param0': 5} with MSE: 369993.00575392466
# Testing parameters {'param0': 7} gives MSE: 158620.86768787168
# New best parameters found: {'param0': 7} with MSE: 158620.86768787168
# Testing parameters {'param0': 11} gives MSE: 43000.220193508816
# New best parameters found: {'param0': 11} with MSE: 43000.220193508816
# Testing parameters {'param0': 13} gives MSE: 24325.641403939826
# New best parameters found: {'param0': 13} with MSE: 24325.641403939826
# Testing parameters {'param0': 17} gives MSE: 8001.5788441592695
# New best parameters found: {'param0': 17} with MSE: 8001.5788441592695
# Testing parameters {'param0': 19} gives MSE: 4448.400057637024
# New best parameters found: {'param0': 19} with MSE: 4448.400057637024
# Testing parameters {'param0': 23} gives MSE: 1092.8432353317723
# New best parameters found: {'param0': 23} with MSE: 1092.8432353317723
# Testing parameters {'param0': 29} gives MSE: 0.0
# New best parameters found: {'param0': 29} with MSE: 0.0
# Testing parameters {'param0': 31} gives MSE: 66.84172407104964
# Testing parameters {'param0': 37} gives MSE: 750.7365590332049
# Testing parameters {'param0': 41} gives MSE: 1375.6432397156634
# Testing parameters {'param0': 43} gives MSE: 1702.2768765720127
# Testing parameters {'param0': 47} gives MSE: 2355.376479590116
# Testing parameters {'param0': 53} gives MSE: 3292.9245795116117
# Testing parameters {'param0': 59} gives MSE: 4151.925247705453
# Testing parameters {'param0': 61} gives MSE: 4419.278040597507
# Best parameters after search: {'param0': 29}
# Testing parameters {'param0': 3, 'param1': 5, 'param2': 2} gives MSE: 10636194869.685217
# New best parameters found: {'param0': 3, 'param1': 5, 'param2': 2} with MSE: 10636194869.685217
# Testing parameters {'param0': 3, 'param1': 5, 'param2': 11} gives MSE: 347825785.3458301
# New best parameters found: {'param0': 3, 'param1': 5, 'param2': 11} with MSE: 347825785.3458301
# Testing parameters {'param0': 3, 'param1': 5, 'param2': 29} gives MSE: 48963890.92521419
# New best parameters found: {'param0': 3, 'param1': 5, 'param2': 29} with MSE: 48963890.92521419
# Testing parameters {'param0': 3, 'param1': 5, 'param2': 43} gives MSE: 21892393.91159926
# New best parameters found: {'param0': 3, 'param1': 5, 'param2': 43} with MSE: 21892393.91159926
# Testing parameters {'param0': 3, 'param1': 5, 'param2': 47} gives MSE: 18234609.64362401
# New best parameters found: {'param0': 3, 'param1': 5, 'param2': 47} with MSE: 18234609.64362401
# Testing parameters {'param0': 3, 'param1': 5, 'param2': 53} gives MSE: 14233889.166396555
# New best parameters found: {'param0': 3, 'param1': 5, 'param2': 53} with MSE: 14233889.166396555
# Testing parameters {'param0': 3, 'param1': 7, 'param2': 2} gives MSE: 5421426091.278936
# Testing parameters {'param0': 3, 'param1': 7, 'param2': 11} gives MSE: 176522091.21022564
# Testing parameters {'param0': 3, 'param1': 7, 'param2': 29} gives MSE: 24629656.984697886
# Testing parameters {'param0': 3, 'param1': 7, 'param2': 43} gives MSE: 10934685.662652085
# New best parameters found: {'param0': 3, 'param1': 7, 'param2': 43} with MSE: 10934685.662652085
# Testing parameters {'param0': 3, 'param1': 7, 'param2': 47} gives MSE: 9089098.32739937
# New best parameters found: {'param0': 3, 'param1': 7, 'param2': 47} with MSE: 9089098.32739937
# Testing parameters {'param0': 3, 'param1': 7, 'param2': 53} gives MSE: 7073019.669993713
# New best parameters found: {'param0': 3, 'param1': 7, 'param2': 53} with MSE: 7073019.669993713
# Testing parameters {'param0': 3, 'param1': 13, 'param2': 2} gives MSE: 1567370607.1274078
# Testing parameters {'param0': 3, 'param1': 13, 'param2': 11} gives MSE: 50367632.64212342
# Testing parameters {'param0': 3, 'param1': 13, 'param2': 29} gives MSE: 6839378.046518487
# New best parameters found: {'param0': 3, 'param1': 13, 'param2': 29} with MSE: 6839378.046518487
# Testing parameters {'param0': 3, 'param1': 13, 'param2': 43} gives MSE: 2970430.690898018
# New best parameters found: {'param0': 3, 'param1': 13, 'param2': 43} with MSE: 2970430.690898018
# Testing parameters {'param0': 3, 'param1': 13, 'param2': 47} gives MSE: 2453263.2494105143
# New best parameters found: {'param0': 3, 'param1': 13, 'param2': 47} with MSE: 2453263.2494105143
# Testing parameters {'param0': 3, 'param1': 13, 'param2': 53} gives MSE: 1890556.8526090381
# New best parameters found: {'param0': 3, 'param1': 13, 'param2': 53} with MSE: 1890556.8526090381
# Testing parameters {'param0': 3, 'param1': 19, 'param2': 2} gives MSE: 731641240.0187638
# Testing parameters {'param0': 3, 'param1': 19, 'param2': 11} gives MSE: 23201601.86735323
# Testing parameters {'param0': 3, 'param1': 19, 'param2': 29} gives MSE: 3063594.1768723107
# Testing parameters {'param0': 3, 'param1': 19, 'param2': 43} gives MSE: 1300019.0759873393
# New best parameters found: {'param0': 3, 'param1': 19, 'param2': 43} with MSE: 1300019.0759873393
# Testing parameters {'param0': 3, 'param1': 19, 'param2': 47} gives MSE: 1066310.4449751703
# New best parameters found: {'param0': 3, 'param1': 19, 'param2': 47} with MSE: 1066310.4449751703
# Testing parameters {'param0': 3, 'param1': 19, 'param2': 53} gives MSE: 813105.7139335588
# New best parameters found: {'param0': 3, 'param1': 19, 'param2': 53} with MSE: 813105.7139335588
# Testing parameters {'param0': 3, 'param1': 37, 'param2': 2} gives MSE: 191263446.48339412
# Testing parameters {'param0': 3, 'param1': 37, 'param2': 11} gives MSE: 5824199.276237106
# Testing parameters {'param0': 3, 'param1': 37, 'param2': 29} gives MSE: 703338.7758114347
# New best parameters found: {'param0': 3, 'param1': 37, 'param2': 29} with MSE: 703338.7758114347
# Testing parameters {'param0': 3, 'param1': 37, 'param2': 43} gives MSE: 275985.8639207703
# New best parameters found: {'param0': 3, 'param1': 37, 'param2': 43} with MSE: 275985.8639207703
# Testing parameters {'param0': 3, 'param1': 37, 'param2': 47} gives MSE: 221003.1244412901
# New best parameters found: {'param0': 3, 'param1': 37, 'param2': 47} with MSE: 221003.1244412901
# Testing parameters {'param0': 3, 'param1': 37, 'param2': 53} gives MSE: 162321.24829392825
# New best parameters found: {'param0': 3, 'param1': 37, 'param2': 53} with MSE: 162321.24829392825
# Testing parameters {'param0': 3, 'param1': 61, 'param2': 2} gives MSE: 69554232.31202549
# Testing parameters {'param0': 3, 'param1': 61, 'param2': 11} gives MSE: 2002725.683381878
# Testing parameters {'param0': 3, 'param1': 61, 'param2': 29} gives MSE: 211636.99122701245
# Testing parameters {'param0': 3, 'param1': 61, 'param2': 43} gives MSE: 72900.04694945794
# New best parameters found: {'param0': 3, 'param1': 61, 'param2': 43} with MSE: 72900.04694945794
# Testing parameters {'param0': 3, 'param1': 61, 'param2': 47} gives MSE: 55931.10228849883
# New best parameters found: {'param0': 3, 'param1': 61, 'param2': 47} with MSE: 55931.10228849883
# Testing parameters {'param0': 3, 'param1': 61, 'param2': 53} gives MSE: 38308.528831893804
# New best parameters found: {'param0': 3, 'param1': 61, 'param2': 53} with MSE: 38308.528831893804
# Testing parameters {'param0': 17, 'param1': 5, 'param2': 2} gives MSE: 327534678.6817682
# Testing parameters {'param0': 17, 'param1': 5, 'param2': 11} gives MSE: 10172010.454919843
# Testing parameters {'param0': 17, 'param1': 5, 'param2': 29} gives MSE: 1283702.1530704594
# Testing parameters {'param0': 17, 'param1': 5, 'param2': 43} gives MSE: 523974.178087777
# Testing parameters {'param0': 17, 'param1': 5, 'param2': 47} gives MSE: 424754.1646989034
# Testing parameters {'param0': 17, 'param1': 5, 'param2': 53} gives MSE: 318041.97826205834
# Testing parameters {'param0': 17, 'param1': 7, 'param2': 2} gives MSE: 166197354.39751142
# Testing parameters {'param0': 17, 'param1': 7, 'param2': 11} gives MSE: 5030078.669952156
# Testing parameters {'param0': 17, 'param1': 7, 'param2': 29} gives MSE: 599014.1106575995
# Testing parameters {'param0': 17, 'param1': 7, 'param2': 43} gives MSE: 232047.84692740135
# Testing parameters {'param0': 17, 'param1': 7, 'param2': 47} gives MSE: 185065.8254696867
# Testing parameters {'param0': 17, 'param1': 7, 'param2': 53} gives MSE: 135051.17230974502
# Testing parameters {'param0': 17, 'param1': 13, 'param2': 2} gives MSE: 47398310.656991184
# Testing parameters {'param0': 17, 'param1': 13, 'param2': 11} gives MSE: 1323837.7245179617
# Testing parameters {'param0': 17, 'param1': 13, 'param2': 29} gives MSE: 129367.12698524415
# Testing parameters {'param0': 17, 'param1': 13, 'param2': 43} gives MSE: 40930.502325967995
# Testing parameters {'param0': 17, 'param1': 13, 'param2': 47} gives MSE: 30475.027760603723
# New best parameters found: {'param0': 17, 'param1': 13, 'param2': 47} with MSE: 30475.027760603723
# Testing parameters {'param0': 17, 'param1': 13, 'param2': 53} gives MSE: 19827.347070750562
# New best parameters found: {'param0': 17, 'param1': 13, 'param2': 53} with MSE: 19827.347070750562
# Testing parameters {'param0': 17, 'param1': 19, 'param2': 2} gives MSE: 21822879.63147592
# Testing parameters {'param0': 17, 'param1': 19, 'param2': 11} gives MSE: 559790.0455325962
# Testing parameters {'param0': 17, 'param1': 19, 'param2': 29} gives MSE: 42867.88885496389
# Testing parameters {'param0': 17, 'param1': 19, 'param2': 43} gives MSE: 9875.555857579862
# New best parameters found: {'param0': 17, 'param1': 19, 'param2': 43} with MSE: 9875.555857579862
# Testing parameters {'param0': 17, 'param1': 19, 'param2': 47} gives MSE: 6463.280645211144
# New best parameters found: {'param0': 17, 'param1': 19, 'param2': 47} with MSE: 6463.280645211144
# Testing parameters {'param0': 17, 'param1': 19, 'param2': 53} gives MSE: 3282.6765778060885
# New best parameters found: {'param0': 17, 'param1': 19, 'param2': 53} with MSE: 3282.6765778060885
# Testing parameters {'param0': 17, 'param1': 37, 'param2': 2} gives MSE: 5469612.963494397
# Testing parameters {'param0': 17, 'param1': 37, 'param2': 11} gives MSE: 105008.44535103944
# Testing parameters {'param0': 17, 'param1': 37, 'param2': 29} gives MSE: 2131.161718159174
# New best parameters found: {'param0': 17, 'param1': 37, 'param2': 29} with MSE: 2131.161718159174
# Testing parameters {'param0': 17, 'param1': 37, 'param2': 43} gives MSE: 83.27264148312979
# New best parameters found: {'param0': 17, 'param1': 37, 'param2': 43} with MSE: 83.27264148312979
# Testing parameters {'param0': 17, 'param1': 37, 'param2': 47} gives MSE: 356.17271305307486
# Testing parameters {'param0': 17, 'param1': 37, 'param2': 53} gives MSE: 944.6181742821836
# Testing parameters {'param0': 17, 'param1': 61, 'param2': 2} gives MSE: 1876673.0338784675
# Testing parameters {'param0': 17, 'param1': 61, 'param2': 11} gives MSE: 21875.601712776
# Testing parameters {'param0': 17, 'param1': 61, 'param2': 29} gives MSE: 426.40214174751634
# Testing parameters {'param0': 17, 'param1': 61, 'param2': 43} gives MSE: 2936.1224522765847
# Testing parameters {'param0': 17, 'param1': 61, 'param2': 47} gives MSE: 3611.7944752556423
# Testing parameters {'param0': 17, 'param1': 61, 'param2': 53} gives MSE: 4528.381873651365
# Testing parameters {'param0': 23, 'param1': 5, 'param2': 2} gives MSE: 178074751.24580553
# Testing parameters {'param0': 23, 'param1': 5, 'param2': 11} gives MSE: 5406064.802805618
# Testing parameters {'param0': 23, 'param1': 5, 'param2': 29} gives MSE: 648317.0731301963
# Testing parameters {'param0': 23, 'param1': 5, 'param2': 43} gives MSE: 252777.39494160574
# Testing parameters {'param0': 23, 'param1': 5, 'param2': 47} gives MSE: 202011.62031062762
# Testing parameters {'param0': 23, 'param1': 5, 'param2': 53} gives MSE: 147899.07212879095
# Testing parameters {'param0': 23, 'param1': 7, 'param2': 2} gives MSE: 90182201.91700917
# Testing parameters {'param0': 23, 'param1': 7, 'param2': 11} gives MSE: 2642094.206830654
# Testing parameters {'param0': 23, 'param1': 7, 'param2': 29} gives MSE: 291383.741728839
# Testing parameters {'param0': 23, 'param1': 7, 'param2': 43} gives MSE: 104840.86393109759
# Testing parameters {'param0': 23, 'param1': 7, 'param2': 47} gives MSE: 81630.71433321162
# Testing parameters {'param0': 23, 'param1': 7, 'param2': 53} gives MSE: 57296.870454659416
# Testing parameters {'param0': 23, 'param1': 13, 'param2': 2} gives MSE: 25567095.6955638
# Testing parameters {'param0': 23, 'param1': 13, 'param2': 11} gives MSE: 669405.589232473
# Testing parameters {'param0': 23, 'param1': 13, 'param2': 29} gives MSE: 54564.33814194641
# Testing parameters {'param0': 23, 'param1': 13, 'param2': 43} gives MSE: 13754.112199857456
# Testing parameters {'param0': 23, 'param1': 13, 'param2': 47} gives MSE: 9365.022117832028
# Testing parameters {'param0': 23, 'param1': 13, 'param2': 53} gives MSE: 5157.967167781858
# Testing parameters {'param0': 23, 'param1': 19, 'param2': 2} gives MSE: 11700419.284058085
# Testing parameters {'param0': 23, 'param1': 19, 'param2': 11} gives MSE: 271183.88754494634
# Testing parameters {'param0': 23, 'param1': 19, 'param2': 29} gives MSE: 14586.851316112434
# Testing parameters {'param0': 23, 'param1': 19, 'param2': 43} gives MSE: 1696.9472819386283
# Testing parameters {'param0': 23, 'param1': 19, 'param2': 47} gives MSE: 737.902635323176
# Testing parameters {'param0': 23, 'param1': 19, 'param2': 53} gives MSE: 101.81891491347871
# Testing parameters {'param0': 23, 'param1': 37, 'param2': 2} gives MSE: 2877643.09042815
# Testing parameters {'param0': 23, 'param1': 37, 'param2': 11} gives MSE: 42955.70645810783
# Testing parameters {'param0': 23, 'param1': 37, 'param2': 29} gives MSE: 3.4741633384787662
# New best parameters found: {'param0': 23, 'param1': 37, 'param2': 29} with MSE: 3.4741633384787662
# Testing parameters {'param0': 23, 'param1': 37, 'param2': 43} gives MSE: 1521.1974119083336
# Testing parameters {'param0': 23, 'param1': 37, 'param2': 47} gives MSE: 2135.082146659375
# Testing parameters {'param0': 23, 'param1': 37, 'param2': 53} gives MSE: 3022.205570621271
# Testing parameters {'param0': 23, 'param1': 61, 'param2': 2} gives MSE: 960968.0664035523
# Testing parameters {'param0': 23, 'param1': 61, 'param2': 11} gives MSE: 5938.657819844199
# Testing parameters {'param0': 23, 'param1': 61, 'param2': 29} gives MSE: 2258.1846704812597
# Testing parameters {'param0': 23, 'param1': 61, 'param2': 43} gives MSE: 5228.47610794358
# Testing parameters {'param0': 23, 'param1': 61, 'param2': 47} gives MSE: 5879.530294347946
# Testing parameters {'param0': 23, 'param1': 61, 'param2': 53} gives MSE: 6723.3723318018965
# Testing parameters {'param0': 31, 'param1': 5, 'param2': 2} gives MSE: 97393636.10435556
# Testing parameters {'param0': 31, 'param1': 5, 'param2': 11} gives MSE: 2866788.5746323885
# Testing parameters {'param0': 31, 'param1': 5, 'param2': 29} gives MSE: 319769.6894259361
# Testing parameters {'param0': 31, 'param1': 5, 'param2': 43} gives MSE: 116357.31021942577
# Testing parameters {'param0': 31, 'param1': 5, 'param2': 47} gives MSE: 90936.80103421088
# Testing parameters {'param0': 31, 'param1': 5, 'param2': 53} gives MSE: 64221.75476423233
# Testing parameters {'param0': 31, 'param1': 7, 'param2': 2} gives MSE: 49193787.581312895
# Testing parameters {'param0': 31, 'param1': 7, 'param2': 11} gives MSE: 1378439.641759461
# Testing parameters {'param0': 31, 'param1': 7, 'param2': 29} gives MSE: 135855.4510804767
# Testing parameters {'param0': 31, 'param1': 7, 'param2': 43} gives MSE: 43397.84594245129
# Testing parameters {'param0': 31, 'param1': 7, 'param2': 47} gives MSE: 32424.5656247774
# Testing parameters {'param0': 31, 'param1': 7, 'param2': 53} gives MSE: 21223.9812233254
# Testing parameters {'param0': 31, 'param1': 13, 'param2': 2} gives MSE: 13835465.079068432
# Testing parameters {'param0': 31, 'param1': 13, 'param2': 11} gives MSE: 330763.11798418046
# Testing parameters {'param0': 31, 'param1': 13, 'param2': 29} gives MSE: 19993.38435934575
# Testing parameters {'param0': 31, 'param1': 13, 'param2': 43} gives MSE: 3036.2117761226477
# Testing parameters {'param0': 31, 'param1': 13, 'param2': 47} gives MSE: 1591.094892258945
# Testing parameters {'param0': 31, 'param1': 13, 'param2': 53} gives MSE: 456.85777725182487
# Testing parameters {'param0': 31, 'param1': 19, 'param2': 2} gives MSE: 6279757.660993487
# Testing parameters {'param0': 31, 'param1': 19, 'param2': 11} gives MSE: 125637.95515316121
# Testing parameters {'param0': 31, 'param1': 19, 'param2': 29} gives MSE: 3328.967280795889
# Testing parameters {'param0': 31, 'param1': 19, 'param2': 43} gives MSE: 1.8158088674527508
# New best parameters found: {'param0': 31, 'param1': 19, 'param2': 43} with MSE: 1.8158088674527508
# Testing parameters {'param0': 31, 'param1': 19, 'param2': 47} gives MSE: 138.21810476797938
# Testing parameters {'param0': 31, 'param1': 19, 'param2': 53} gives MSE: 596.5463341273739
# Testing parameters {'param0': 31, 'param1': 37, 'param2': 2} gives MSE: 1504744.1414565465
# Testing parameters {'param0': 31, 'param1': 37, 'param2': 11} gives MSE: 14850.086698536285
# Testing parameters {'param0': 31, 'param1': 37, 'param2': 29} gives MSE: 931.954090863277
# Testing parameters {'param0': 31, 'param1': 37, 'param2': 43} gives MSE: 3702.501771089319
# Testing parameters {'param0': 31, 'param1': 37, 'param2': 47} gives MSE: 4381.566179708207
# Testing parameters {'param0': 31, 'param1': 37, 'param2': 53} gives MSE: 5285.060833107459
# Testing parameters {'param0': 31, 'param1': 61, 'param2': 2} gives MSE: 483582.48508225975
# Testing parameters {'param0': 31, 'param1': 61, 'param2': 11} gives MSE: 638.3059626161813
# Testing parameters {'param0': 31, 'param1': 61, 'param2': 29} gives MSE: 4511.522276184675
# Testing parameters {'param0': 31, 'param1': 61, 'param2': 43} gives MSE: 7320.316072213593
# Testing parameters {'param0': 31, 'param1': 61, 'param2': 47} gives MSE: 7885.621931974809
# Testing parameters {'param0': 31, 'param1': 61, 'param2': 53} gives MSE: 8601.949379823063
# Testing parameters {'param0': 41, 'param1': 5, 'param2': 2} gives MSE: 55229156.85978493
# Testing parameters {'param0': 41, 'param1': 5, 'param2': 11} gives MSE: 1562585.0806593073
# Testing parameters {'param0': 41, 'param1': 5, 'param2': 29} gives MSE: 157926.6045797249
# Testing parameters {'param0': 41, 'param1': 5, 'param2': 43} gives MSE: 51871.99141073535
# Testing parameters {'param0': 41, 'param1': 5, 'param2': 47} gives MSE: 39143.48010139769
# Testing parameters {'param0': 41, 'param1': 5, 'param2': 53} gives MSE: 26066.331789665623
# Testing parameters {'param0': 41, 'param1': 7, 'param2': 2} gives MSE: 27804306.04165148
# Testing parameters {'param0': 41, 'param1': 7, 'param2': 11} gives MSE: 735394.7632791521
# Testing parameters {'param0': 41, 'param1': 7, 'param2': 29} gives MSE: 61765.75004473258
# Testing parameters {'param0': 41, 'param1': 7, 'param2': 43} gives MSE: 16218.469398724885
# Testing parameters {'param0': 41, 'param1': 7, 'param2': 47} gives MSE: 11233.779365834793
# Testing parameters {'param0': 41, 'param1': 7, 'param2': 53} gives MSE: 6398.73513183897
# Testing parameters {'param0': 41, 'param1': 13, 'param2': 2} gives MSE: 7740776.094270538
# Testing parameters {'param0': 41, 'param1': 13, 'param2': 11} gives MSE: 163771.79174655018
# Testing parameters {'param0': 41, 'param1': 13, 'param2': 29} gives MSE: 5890.721403487683
# Testing parameters {'param0': 41, 'param1': 13, 'param2': 43} gives MSE: 132.3130073735723
# Testing parameters {'param0': 41, 'param1': 13, 'param2': 47} gives MSE: 0.0
# New best parameters found: {'param0': 41, 'param1': 13, 'param2': 47} with MSE: 0.0
# Testing parameters {'param0': 41, 'param1': 13, 'param2': 53} gives MSE: 195.96126341256837
# Testing parameters {'param0': 41, 'param1': 19, 'param2': 2} gives MSE: 3476654.388366678
# Testing parameters {'param0': 41, 'param1': 19, 'param2': 11} gives MSE: 56569.0653393555
# Testing parameters {'param0': 41, 'param1': 19, 'param2': 29} gives MSE: 181.30875356994997
# Testing parameters {'param0': 41, 'param1': 19, 'param2': 43} gives MSE: 972.0974343671959
# Testing parameters {'param0': 41, 'param1': 19, 'param2': 47} gives MSE: 1524.806617523282
# Testing parameters {'param0': 41, 'param1': 19, 'param2': 53} gives MSE: 2364.563056579358
# Testing parameters {'param0': 41, 'param1': 37, 'param2': 2} gives MSE: 805201.5480448736
# Testing parameters {'param0': 41, 'param1': 37, 'param2': 11} gives MSE: 3841.4128572967284
# Testing parameters {'param0': 41, 'param1': 37, 'param2': 29} gives MSE: 2834.6795877995687
# Testing parameters {'param0': 41, 'param1': 37, 'param2': 43} gives MSE: 5801.379304308757
# Testing parameters {'param0': 41, 'param1': 37, 'param2': 47} gives MSE: 6433.369629521166
# Testing parameters {'param0': 41, 'param1': 37, 'param2': 53} gives MSE: 7246.558773017735
# Testing parameters {'param0': 41, 'param1': 61, 'param2': 2} gives MSE: 245650.42855704727
# Testing parameters {'param0': 41, 'param1': 61, 'param2': 11} gives MSE: 122.2578994196229
# Testing parameters {'param0': 41, 'param1': 61, 'param2': 29} gives MSE: 6552.106111216004
# Testing parameters {'param0': 41, 'param1': 61, 'param2': 43} gives MSE: 8996.608890776726
# Testing parameters {'param0': 41, 'param1': 61, 'param2': 47} gives MSE: 9467.651731055606
# Testing parameters {'param0': 41, 'param1': 61, 'param2': 53} gives MSE: 10057.1154293563
# Testing parameters {'param0': 59, 'param1': 5, 'param2': 2} gives MSE: 26282329.832509764
# Testing parameters {'param0': 59, 'param1': 5, 'param2': 11} gives MSE: 690465.6575389495
# Testing parameters {'param0': 59, 'param1': 5, 'param2': 29} gives MSE: 56850.82054347249
# Testing parameters {'param0': 59, 'param1': 5, 'param2': 43} gives MSE: 14531.05044511608
# Testing parameters {'param0': 59, 'param1': 5, 'param2': 47} gives MSE: 9952.435035117285
# Testing parameters {'param0': 59, 'param1': 5, 'param2': 53} gives MSE: 5545.702878882981
# Testing parameters {'param0': 59, 'param1': 7, 'param2': 2} gives MSE: 13151852.999521716
# Testing parameters {'param0': 59, 'param1': 7, 'param2': 11} gives MSE: 311587.9207502899
# Testing parameters {'param0': 59, 'param1': 7, 'param2': 29} gives MSE: 18219.66264765909
# Testing parameters {'param0': 59, 'param1': 7, 'param2': 43} gives MSE: 2577.957627011984
# Testing parameters {'param0': 59, 'param1': 7, 'param2': 47} gives MSE: 1290.8680684670824
# Testing parameters {'param0': 59, 'param1': 7, 'param2': 53} gives MSE: 319.0739567348653
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 2} gives MSE: 3593623.6137273647
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 11} gives MSE: 59291.41067181556
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 29} gives MSE: 243.68396498196685
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 43} gives MSE: 883.9713811352038
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 47} gives MSE: 1423.182045484959
# Testing parameters {'param0': 59, 'param1': 13, 'param2': 53} gives MSE: 2251.781251508974
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 2} gives MSE: 1582562.0355710178
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 11} gives MSE: 16270.357529532557
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 29} gives MSE: 804.7426268155651
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 43} gives MSE: 3527.348423689532
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 47} gives MSE: 4206.9068528278085
# Testing parameters {'param0': 59, 'param1': 19, 'param2': 53} gives MSE: 5114.619991639431
# Testing parameters {'param0': 59, 'param1': 37, 'param2': 2} gives MSE: 343212.4685696757
# Testing parameters {'param0': 59, 'param1': 37, 'param2': 11} gives MSE: 28.5707298359243
# Testing parameters {'param0': 59, 'param1': 37, 'param2': 29} gives MSE: 5583.610555140012
# Testing parameters {'param0': 59, 'param1': 37, 'param2': 43} gives MSE: 8218.246822997075
# Testing parameters {'param0': 59, 'param1': 37, 'param2': 47} gives MSE: 8735.341464962265
# Testing parameters {'param0': 59, 'param1': 37, 'param2': 53} gives MSE: 9385.91704932297
# Testing parameters {'param0': 59, 'param1': 61, 'param2': 2} gives MSE: 94062.86328123523
# Testing parameters {'param0': 59, 'param1': 61, 'param2': 11} gives MSE: 2061.957619022545
# Testing parameters {'param0': 59, 'param1': 61, 'param2': 29} gives MSE: 8831.311248460186
# Testing parameters {'param0': 59, 'param1': 61, 'param2': 43} gives MSE: 10740.85855511505
# Testing parameters {'param0': 59, 'param1': 61, 'param2': 47} gives MSE: 11096.85923434794
# Testing parameters {'param0': 59, 'param1': 61, 'param2': 53} gives MSE: 11537.934935546959
# Best parameters after search: {'param0': 41, 'param1': 13, 'param2': 47}
# Testing parameters {'param1': 3, 'param0': 2} gives MSE: 61412601.78180003
# New best parameters found: {'param1': 3, 'param0': 2} with MSE: 61412601.78180003
# Testing parameters {'param1': 5, 'param0': 2} gives MSE: 21634372.692003045
# New best parameters found: {'param1': 5, 'param0': 2} with MSE: 21634372.692003045
# Testing parameters {'param1': 7, 'param0': 2} gives MSE: 10798647.311821401
# New best parameters found: {'param1': 7, 'param0': 2} with MSE: 10798647.311821401
# Testing parameters {'param1': 13, 'param0': 2} gives MSE: 2927384.139103828
# New best parameters found: {'param1': 13, 'param0': 2} with MSE: 2927384.139103828
# Testing parameters {'param1': 23, 'param0': 2} gives MSE: 831672.8088153346
# New best parameters found: {'param1': 23, 'param0': 2} with MSE: 831672.8088153346
# Testing parameters {'param1': 43, 'param0': 2} gives MSE: 183908.26783131293
# New best parameters found: {'param1': 43, 'param0': 2} with MSE: 183908.26783131293
# Testing parameters {'param1': 47, 'param0': 2} gives MSE: 145589.2612381239
# New best parameters found: {'param1': 47, 'param0': 2} with MSE: 145589.2612381239
# Testing parameters {'param1': 53, 'param0': 2} gives MSE: 104987.84699968614
# New best parameters found: {'param1': 53, 'param0': 2} with MSE: 104987.84699968614
# Testing parameters {'param1': 59, 'param0': 2} gives MSE: 77383.37943317766
# New best parameters found: {'param1': 59, 'param0': 2} with MSE: 77383.37943317766
# Testing parameters {'param1': 3, 'param0': 11} gives MSE: 1745424.9666385287
# Testing parameters {'param1': 5, 'param0': 11} gives MSE: 550552.2512738451
# Testing parameters {'param1': 7, 'param0': 11} gives MSE: 243822.1954947394
# Testing parameters {'param1': 13, 'param0': 11} gives MSE: 43010.235285272014
# New best parameters found: {'param1': 13, 'param0': 11} with MSE: 43010.235285272014
# Testing parameters {'param1': 23, 'param0': 11} gives MSE: 3858.4644784379043
# New best parameters found: {'param1': 23, 'param0': 11} with MSE: 3858.4644784379043
# Testing parameters {'param1': 43, 'param0': 11} gives MSE: 661.6561644750698
# New best parameters found: {'param1': 43, 'param0': 11} with MSE: 661.6561644750698
# Testing parameters {'param1': 47, 'param0': 11} gives MSE: 1177.842344716804
# Testing parameters {'param1': 53, 'param0': 11} gives MSE: 2005.4392457289011
# Testing parameters {'param1': 59, 'param0': 11} gives MSE: 2821.3735652675064
# Testing parameters {'param1': 3, 'param0': 17} gives MSE: 656306.9849517588
# Testing parameters {'param1': 5, 'param0': 17} gives MSE: 189557.0886688776
# Testing parameters {'param1': 7, 'param0': 17} gives MSE: 75501.86294234262
# Testing parameters {'param1': 13, 'param0': 17} gives MSE: 8003.442475229394
# Testing parameters {'param1': 23, 'param0': 17} gives MSE: 20.592768393522327
# New best parameters found: {'param1': 23, 'param0': 17} with MSE: 20.592768393522327
# Testing parameters {'param1': 43, 'param0': 17} gives MSE: 3766.8987636930133
# Testing parameters {'param1': 47, 'param0': 17} gives MSE: 4480.675801515115
# Testing parameters {'param1': 53, 'param0': 17} gives MSE: 5432.8181763938
# Testing parameters {'param1': 59, 'param0': 17} gives MSE: 6256.896612210325
# Testing parameters {'param1': 3, 'param0': 19} gives MSE: 506246.9546932147
# Testing parameters {'param1': 5, 'param0': 19} gives MSE: 141534.78336922225
# Testing parameters {'param1': 7, 'param0': 19} gives MSE: 54061.55696977384
# Testing parameters {'param1': 13, 'param0': 19} gives MSE: 4449.436125233334
# Testing parameters {'param1': 23, 'param0': 19} gives MSE: 302.7971654223062
# Testing parameters {'param1': 43, 'param0': 19} gives MSE: 4658.793044051776
# Testing parameters {'param1': 47, 'param0': 19} gives MSE: 5363.010706021396
# Testing parameters {'param1': 53, 'param0': 19} gives MSE: 6286.867917782521
# Testing parameters {'param1': 59, 'param0': 19} gives MSE: 7075.332016711171
# Testing parameters {'param1': 3, 'param0': 29} gives MSE: 178471.8268010259
# Testing parameters {'param1': 5, 'param0': 29} gives MSE: 41119.908894956374
# Testing parameters {'param1': 7, 'param0': 29} gives MSE: 11800.994261945385
# Testing parameters {'param1': 13, 'param0': 29} gives MSE: 0.0
# New best parameters found: {'param1': 13, 'param0': 29} with MSE: 0.0
# Testing parameters {'param1': 23, 'param0': 29} gives MSE: 3036.382686595905
# Testing parameters {'param1': 43, 'param0': 29} gives MSE: 7818.398037254246
# Testing parameters {'param1': 47, 'param0': 29} gives MSE: 8405.707949469775
# Testing parameters {'param1': 53, 'param0': 29} gives MSE: 9149.143132555262
# Testing parameters {'param1': 59, 'param0': 29} gives MSE: 9763.91114506963
# Testing parameters {'param1': 3, 'param0': 31} gives MSE: 149790.04851679027
# Testing parameters {'param1': 5, 'param0': 31} gives MSE: 32949.94780793167
# Testing parameters {'param1': 7, 'param0': 31} gives MSE: 8732.381000861424
# Testing parameters {'param1': 13, 'param0': 31} gives MSE: 66.85729203784543
# Testing parameters {'param1': 23, 'param0': 31} gives MSE: 3567.0703411647364
# Testing parameters {'param1': 43, 'param0': 31} gives MSE: 8261.666584086017
# Testing parameters {'param1': 47, 'param0': 31} gives MSE: 8825.525739355224
# Testing parameters {'param1': 53, 'param0': 31} gives MSE: 9536.839262852329
# Testing parameters {'param1': 59, 'param0': 31} gives MSE: 10123.204268353733
# Testing parameters {'param1': 3, 'param0': 37} gives MSE: 92242.16637789182
# Testing parameters {'param1': 5, 'param0': 37} gives MSE: 17300.998921471786
# Testing parameters {'param1': 7, 'param0': 37} gives MSE: 3334.0849789653344
# Testing parameters {'param1': 13, 'param0': 37} gives MSE: 750.9114115222129
# Testing parameters {'param1': 23, 'param0': 37} gives MSE: 4983.216336695555
# Testing parameters {'param1': 43, 'param0': 37} gives MSE: 9352.101090587745
# Testing parameters {'param1': 47, 'param0': 37} gives MSE: 9852.971568553443
# Testing parameters {'param1': 53, 'param0': 37} gives MSE: 10480.146307339563
# Testing parameters {'param1': 59, 'param0': 37} gives MSE: 10993.606778905416
# Testing parameters {'param1': 3, 'param0': 41} gives MSE: 68496.65899997018
# Testing parameters {'param1': 5, 'param0': 41} gives MSE: 11307.363406718378
# Testing parameters {'param1': 7, 'param0': 41} gives MSE: 1579.5500945495025
# Testing parameters {'param1': 13, 'param0': 41} gives MSE: 1375.9636379186773
# Testing parameters {'param1': 23, 'param0': 41} gives MSE: 5786.575918781188
# Testing parameters {'param1': 43, 'param0': 41} gives MSE: 9927.365560164755
# Testing parameters {'param1': 47, 'param0': 41} gives MSE: 10392.311252262278
# Testing parameters {'param1': 53, 'param0': 41} gives MSE: 10972.494971244936
# Testing parameters {'param1': 59, 'param0': 41} gives MSE: 11445.951918953557
# Testing parameters {'param1': 3, 'param0': 61} gives MSE: 18051.506781734504
# Testing parameters {'param1': 5, 'param0': 61} gives MSE: 895.1122334027046
# Testing parameters {'param1': 7, 'param0': 61} gives MSE: 220.24012104619044
# Testing parameters {'param1': 13, 'param0': 61} gives MSE: 4420.307325445458
# Testing parameters {'param1': 23, 'param0': 61} gives MSE: 8589.968237019699
# Testing parameters {'param1': 43, 'param0': 61} gives MSE: 11777.011554031964
# Testing parameters {'param1': 47, 'param0': 61} gives MSE: 12115.894603970255
# Testing parameters {'param1': 53, 'param0': 61} gives MSE: 12534.79326096249
# Testing parameters {'param1': 59, 'param0': 61} gives MSE: 12873.586554894464
# Best parameters after search: {'param1': 13, 'param0': 29}
# Testing parameters {'param0': 2, 'param1': 11, 'param2': 3} gives MSE: 12529280.193253314
# New best parameters found: {'param0': 2, 'param1': 11, 'param2': 3} with MSE: 12529280.193253314
# Testing parameters {'param0': 2, 'param1': 11, 'param2': 5} gives MSE: 4301989.477496359
# New best parameters found: {'param0': 2, 'param1': 11, 'param2': 5} with MSE: 4301989.477496359
# Testing parameters {'param0': 2, 'param1': 11, 'param2': 29} gives MSE: 64934.326016588384
# New best parameters found: {'param0': 2, 'param1': 11, 'param2': 29} with MSE: 64934.326016588384
# Testing parameters {'param0': 2, 'param1': 11, 'param2': 31} gives MSE: 53069.953023494985
# New best parameters found: {'param0': 2, 'param1': 11, 'param2': 31} with MSE: 53069.953023494985
# Testing parameters {'param0': 2, 'param1': 11, 'param2': 37} gives MSE: 29884.597535371217
# New best parameters found: {'param0': 2, 'param1': 11, 'param2': 37} with MSE: 29884.597535371217
# Testing parameters {'param0': 2, 'param1': 11, 'param2': 61} gives MSE: 3135.0330177950914
# New best parameters found: {'param0': 2, 'param1': 11, 'param2': 61} with MSE: 3135.0330177950914
# Testing parameters {'param0': 2, 'param1': 13, 'param2': 3} gives MSE: 8856574.880804865
# Testing parameters {'param0': 2, 'param1': 13, 'param2': 5} gives MSE: 3013419.2030642987
# Testing parameters {'param0': 2, 'param1': 13, 'param2': 29} gives MSE: 38616.65009983808
# Testing parameters {'param0': 2, 'param1': 13, 'param2': 31} gives MSE: 30912.747513867023
# Testing parameters {'param0': 2, 'param1': 13, 'param2': 37} gives MSE: 16171.813283326774
# Testing parameters {'param0': 2, 'param1': 13, 'param2': 61} gives MSE: 799.1796917444852
# ...
# New best parameters found: {'param1': 61, 'param0': 7} with MSE: 388205.8648291604
# Testing parameters {'param1': 11, 'param0': 23} gives MSE: 1299127.8995387745
# Testing parameters {'param1': 13, 'param0': 23} gives MSE: 892467.8718106074
# Testing parameters {'param1': 17, 'param0': 23} gives MSE: 479194.3998230693
# Testing parameters {'param1': 19, 'param0': 23} gives MSE: 367076.72650953056
# New best parameters found: {'param1': 19, 'param0': 23} with MSE: 367076.72650953056
# Testing parameters {'param1': 29, 'param0': 23} gives MSE: 124407.72059651712
# New best parameters found: {'param1': 29, 'param0': 23} with MSE: 124407.72059651712
# Testing parameters {'param1': 43, 'param0': 23} gives MSE: 38460.18219789583
# New best parameters found: {'param1': 43, 'param0': 23} with MSE: 38460.18219789583
# Testing parameters {'param1': 47, 'param0': 23} gives MSE: 28393.938610008856
# New best parameters found: {'param1': 47, 'param0': 23} with MSE: 28393.938610008856
# Testing parameters {'param1': 59, 'param0': 23} gives MSE: 11694.797110166784
# New best parameters found: {'param1': 59, 'param0': 23} with MSE: 11694.797110166784
# Testing parameters {'param1': 61, 'param0': 23} gives MSE: 10078.35556744748
# New best parameters found: {'param1': 61, 'param0': 23} with MSE: 10078.35556744748
# Testing parameters {'param1': 11, 'param0': 31} gives MSE: 660235.8198724462
# Testing parameters {'param1': 13, 'param0': 31} gives MSE: 445965.44938372367
# Testing parameters {'param1': 17, 'param0': 31} gives MSE: 230873.13722383563
# Testing parameters {'param1': 19, 'param0': 31} gives MSE: 173398.57514749138
# Testing parameters {'param1': 29, 'param0': 31} gives MSE: 52252.36816573915
# Testing parameters {'param1': 43, 'param0': 31} gives MSE: 12633.559348838167
# Testing parameters {'param1': 47, 'param0': 31} gives MSE: 8448.551036924704
# New best parameters found: {'param1': 47, 'param0': 31} with MSE: 8448.551036924704
# Testing parameters {'param1': 59, 'param0': 31} gives MSE: 2221.3217720315834
# New best parameters found: {'param1': 59, 'param0': 31} with MSE: 2221.3217720315834
# Testing parameters {'param1': 61, 'param0': 31} gives MSE: 1712.288541764531
# New best parameters found: {'param1': 61, 'param0': 31} with MSE: 1712.288541764531
# Testing parameters {'param1': 11, 'param0': 37} gives MSE: 435576.9347924995
# Testing parameters {'param1': 13, 'param0': 37} gives MSE: 290210.3682707618
# Testing parameters {'param1': 17, 'param0': 37} gives MSE: 145750.7291445119
# Testing parameters {'param1': 19, 'param0': 37} gives MSE: 107638.85340693299
# Testing parameters {'param1': 29, 'param0': 37} gives MSE: 29144.546982116597
# Testing parameters {'param1': 43, 'param0': 37} gives MSE: 5383.227867310014
# Testing parameters {'param1': 47, 'param0': 37} gives MSE: 3159.4473084595365
# Testing parameters {'param1': 59, 'param0': 37} gives MSE: 349.17818780821483
# New best parameters found: {'param1': 59, 'param0': 37} with MSE: 349.17818780821483
# Testing parameters {'param1': 61, 'param0': 37} gives MSE: 192.3166443986227
# New best parameters found: {'param1': 61, 'param0': 37} with MSE: 192.3166443986227
# Testing parameters {'param1': 11, 'param0': 41} gives MSE: 339981.25798258575
# Testing parameters {'param1': 13, 'param0': 41} gives MSE: 224334.52077021822
# Testing parameters {'param1': 17, 'param0': 41} gives MSE: 110232.04092729221
# Testing parameters {'param1': 19, 'param0': 41} gives MSE: 80406.60346685324
# Testing parameters {'param1': 29, 'param0': 41} gives MSE: 20035.68979266317
# Testing parameters {'param1': 43, 'param0': 41} gives MSE: 2883.423523623428
# Testing parameters {'param1': 47, 'param0': 41} gives MSE: 1460.0263493553648
# Testing parameters {'param1': 59, 'param0': 41} gives MSE: 18.908466402019013
# New best parameters found: {'param1': 59, 'param0': 41} with MSE: 18.908466402019013
# Testing parameters {'param1': 61, 'param0': 41} gives MSE: 0.0
# New best parameters found: {'param1': 61, 'param0': 41} with MSE: 0.0
# Testing parameters {'param1': 11, 'param0': 53} gives MSE: 178098.57077831685
# Testing parameters {'param1': 13, 'param0': 53} gives MSE: 113809.43859206447
# Testing parameters {'param1': 17, 'param0': 53} gives MSE: 51890.84244670098
# Testing parameters {'param1': 19, 'param0': 53} gives MSE: 36219.511784630784
# Testing parameters {'param1': 29, 'param0': 53} gives MSE: 6473.015857776729
# Testing parameters {'param1': 43, 'param0': 53} gives MSE: 156.14124456471149
# Testing parameters {'param1': 47, 'param0': 53} gives MSE: 0.26518739862310825
# Testing parameters {'param1': 59, 'param0': 53} gives MSE: 659.4672641293743
# Testing parameters {'param1': 61, 'param0': 53} gives MSE: 843.5505075241825
# Best parameters after search: {'param1': 61, 'param0': 41}
# Testing parameters {'param0': 2} gives MSE: 1150792.540823937
# New best parameters found: {'param0': 2} with MSE: 1150792.540823937
# Testing parameters {'param0': 3} gives MSE: 453060.96186224965
# New best parameters found: {'param0': 3} with MSE: 453060.96186224965
# Testing parameters {'param0': 5} gives MSE: 124874.92761328255
# New best parameters found: {'param0': 5} with MSE: 124874.92761328255
# Testing parameters {'param0': 7} gives MSE: 46808.59427403346
# New best parameters found: {'param0': 7} with MSE: 46808.59427403346
# Testing parameters {'param0': 11} gives MSE: 8424.687307355882
# New best parameters found: {'param0': 11} with MSE: 8424.687307355882
# Testing parameters {'param0': 13} gives MSE: 3392.930650040885
# New best parameters found: {'param0': 13} with MSE: 3392.930650040885
# Testing parameters {'param0': 17} gives MSE: 220.45570159819687
# New best parameters found: {'param0': 17} with MSE: 220.45570159819687
# Testing parameters {'param0': 19} gives MSE: 0.0
# New best parameters found: {'param0': 19} with MSE: 0.0
# Testing parameters {'param0': 23} gives MSE: 481.75196795371545
# Testing parameters {'param0': 29} gives MSE: 1893.9268062389676
# Testing parameters {'param0': 31} gives MSE: 2386.702517614608
# Testing parameters {'param0': 37} gives MSE: 3769.647566626873
# Testing parameters {'param0': 41} gives MSE: 4586.029404632565
# Testing parameters {'param0': 43} gives MSE: 4961.8628868093865
# Testing parameters {'param0': 47} gives MSE: 5653.007135051272
# Testing parameters {'param0': 53} gives MSE: 6554.888092980775
# Testing parameters {'param0': 59} gives MSE: 7321.079892200962
# Testing parameters {'param0': 61} gives MSE: 7550.889199943182
# Best parameters after search: {'param0': 19}
# Testing parameters {'param0': 2} gives MSE: 4590065.466340209
# New best parameters found: {'param0': 2} with MSE: 4590065.466340209
# Testing parameters {'param0': 3} gives MSE: 1925121.3348169732
# New best parameters found: {'param0': 3} with MSE: 1925121.3348169732
# Testing parameters {'param0': 5} gives MSE: 613907.2049021879
# New best parameters found: {'param0': 5} with MSE: 613907.2049021879
# Testing parameters {'param0': 7} gives MSE: 275289.2241370221
# New best parameters found: {'param0': 7} with MSE: 275289.2241370221
# Testing parameters {'param0': 11} gives MSE: 83734.43765210947
# New best parameters found: {'param0': 11} with MSE: 83734.43765210947
# Testing parameters {'param0': 13} gives MSE: 51083.25484578116
# New best parameters found: {'param0': 13} with MSE: 51083.25484578116
# Testing parameters {'param0': 17} gives MSE: 20744.593591255794
# New best parameters found: {'param0': 17} with MSE: 20744.593591255794
# Testing parameters {'param0': 19} gives MSE: 13451.805855338145
# New best parameters found: {'param0': 19} with MSE: 13451.805855338145
# Testing parameters {'param0': 23} gives MSE: 5553.198295761313
# New best parameters found: {'param0': 23} with MSE: 5553.198295761313
# Testing parameters {'param0': 29} gives MSE: 1140.582648822436
# New best parameters found: {'param0': 29} with MSE: 1140.582648822436
# Testing parameters {'param0': 31} gives MSE: 561.4639743065178
# New best parameters found: {'param0': 31} with MSE: 561.4639743065178
# Testing parameters {'param0': 37} gives MSE: 0.0
# New best parameters found: {'param0': 37} with MSE: 0.0
# Testing parameters {'param0': 41} gives MSE: 142.65764539852287
# Testing parameters {'param0': 43} gives MSE: 291.81551071312253
# Testing parameters {'param0': 47} gives MSE: 678.4956482427484
# Testing parameters {'param0': 53} gives MSE: 1365.9380671550994
# Testing parameters {'param0': 59} gives MSE: 2083.9347695852457
# Testing parameters {'param0': 61} gives MSE: 2320.0940792628357
# Best parameters after search: {'param0': 37}
# Testing parameters {'param1': 3, 'param0': 2} gives MSE: 40267929.82071778
# New best parameters found: {'param1': 3, 'param0': 2} with MSE: 40267929.82071778
# Testing parameters {'param1': 5, 'param0': 2} gives MSE: 14105995.788030488
# New best parameters found: {'param1': 5, 'param0': 2} with MSE: 14105995.788030488
# Testing parameters {'param1': 7, 'param0': 2} gives MSE: 7000442.519478763
# New best parameters found: {'param1': 7, 'param0': 2} with MSE: 7000442.519478763
# Testing parameters {'param1': 13, 'param0': 2} gives MSE: 1863530.3216090081
# New best parameters found: {'param1': 13, 'param0': 2} with MSE: 1863530.3216090081
# Testing parameters {'param1': 19, 'param0': 2} gives MSE: 797925.0061051028
# New best parameters found: {'param1': 19, 'param0': 2} with MSE: 797925.0061051028
# Testing parameters {'param1': 31, 'param0': 2} gives MSE: 247531.34107351885
# New best parameters found: {'param1': 31, 'param0': 2} with MSE: 247531.34107351885
# Testing parameters {'param1': 41, 'param0': 2} gives MSE: 118816.92176964755
# New best parameters found: {'param1': 41, 'param0': 2} with MSE: 118816.92176964755
# Testing parameters {'param1': 53, 'param0': 2} gives MSE: 56373.53437613738
# New best parameters found: {'param1': 53, 'param0': 2} with MSE: 56373.53437613738
# Testing parameters {'param1': 61, 'param0': 2} gives MSE: 35859.49526892467
# New best parameters found: {'param1': 61, 'param0': 2} with MSE: 35859.49526892467
# Testing parameters {'param1': 3, 'param0': 11} gives MSE: 1098650.3038476107
# Testing parameters {'param1': 5, 'param0': 11} gives MSE: 333244.2058859313
# Testing parameters {'param1': 7, 'param0': 11} gives MSE: 140971.83671557668
# Testing parameters {'param1': 13, 'param0': 11} gives MSE: 20335.73485904943
# New best parameters found: {'param1': 13, 'param0': 11} with MSE: 20335.73485904943
# Testing parameters {'param1': 19, 'param0': 11} gives MSE: 3227.7571685656203
# New best parameters found: {'param1': 19, 'param0': 11} with MSE: 3227.7571685656203
# Testing parameters {'param1': 31, 'param0': 11} gives MSE: 229.20759091372383
# New best parameters found: {'param1': 31, 'param0': 11} with MSE: 229.20759091372383
# Testing parameters {'param1': 41, 'param0': 11} gives MSE: 1842.6684765511575
# Testing parameters {'param1': 53, 'param0': 11} gives MSE: 3897.434982620567
# Testing parameters {'param1': 61, 'param0': 11} gives MSE: 5064.9618629806055
# Testing parameters {'param1': 3, 'param0': 17} gives MSE: 400274.0514321223
# Testing parameters {'param1': 5, 'param0': 17} gives MSE: 107569.07218723447
# Testing parameters {'param1': 7, 'param0': 17} gives MSE: 38964.27726260851
# Testing parameters {'param1': 13, 'param0': 17} gives MSE: 2182.7962473363546
# Testing parameters {'param1': 19, 'param0': 17} gives MSE: 77.2783941512831
# New best parameters found: {'param1': 19, 'param0': 17} with MSE: 77.2783941512831
# Testing parameters {'param1': 31, 'param0': 17} gives MSE: 3063.46850461642
# Testing parameters {'param1': 41, 'param0': 17} gives MSE: 5377.031584479877
# Testing parameters {'param1': 53, 'param0': 17} gives MSE: 7387.044081965545
# Testing parameters {'param1': 61, 'param0': 17} gives MSE: 8391.041862214133
# Testing parameters {'param1': 3, 'param0': 23} gives MSE: 188319.61609974012
# Testing parameters {'param1': 5, 'param0': 23} gives MSE: 43576.06194060603
# Testing parameters {'param1': 7, 'param0': 23} gives MSE: 12595.693704649686
# Testing parameters {'param1': 13, 'param0': 23} gives MSE: 0.7453073198017547
# New best parameters found: {'param1': 13, 'param0': 23} with MSE: 0.7453073198017547
# Testing parameters {'param1': 19, 'param0': 23} gives MSE: 1613.3653099806122
# Testing parameters {'param1': 31, 'param0': 23} gives MSE: 5562.027659214504
# Testing parameters {'param1': 41, 'param0': 23} gives MSE: 7720.83804295543
# Testing parameters {'param1': 53, 'param0': 23} gives MSE: 9447.03932142862
# Testing parameters {'param1': 61, 'param0': 23} gives MSE: 10276.982543470433
# Testing parameters {'param1': 3, 'param0': 29} gives MSE: 100787.53260903497
# Testing parameters {'param1': 5, 'param0': 29} gives MSE: 19281.062575038235
# Testing parameters {'param1': 7, 'param0': 29} gives MSE: 3882.1994829753207
# Testing parameters {'param1': 13, 'param0': 29} gives MSE: 676.958827848854
# Testing parameters {'param1': 19, 'param0': 29} gives MSE: 3429.214026880512
# Testing parameters {'param1': 31, 'param0': 29} gives MSE: 7370.564589978054
# Testing parameters {'param1': 41, 'param0': 29} gives MSE: 9291.375120200835
# Testing parameters {'param1': 53, 'param0': 29} gives MSE: 10772.263753793315
# Testing parameters {'param1': 61, 'param0': 29} gives MSE: 11471.341721009005
# Testing parameters {'param1': 3, 'param0': 37} gives MSE: 48806.6518765369
# Testing parameters {'param1': 5, 'param0': 37} gives MSE: 6549.230768815651
# Testing parameters {'param1': 7, 'param0': 37} gives MSE: 438.0430805539593
# Testing parameters {'param1': 13, 'param0': 37} gives MSE: 2332.773801766651
# Testing parameters {'param1': 19, 'param0': 37} gives MSE: 5447.023237137747
# Testing parameters {'param1': 31, 'param0': 37} gives MSE: 9062.158672729738
# Testing parameters {'param1': 41, 'param0': 37} gives MSE: 10703.202943347153
# Testing parameters {'param1': 53, 'param0': 37} gives MSE: 11936.548324576683
# Testing parameters {'param1': 61, 'param0': 37} gives MSE: 12511.009521352496
# Testing parameters {'param1': 3, 'param0': 43} gives MSE: 29613.875421154135
# Testing parameters {'param1': 5, 'param0': 43} gives MSE: 2665.248787903871
# Testing parameters {'param1': 7, 'param0': 43} gives MSE: 0.0
# New best parameters found: {'param1': 7, 'param0': 43} with MSE: 0.0
# Testing parameters {'param1': 13, 'param0': 43} gives MSE: 3548.408149576161
# Testing parameters {'param1': 19, 'param0': 43} gives MSE: 6644.664568181399
# Testing parameters {'param1': 31, 'param0': 43} gives MSE: 9984.28266020181
# Testing parameters {'param1': 41, 'param0': 43} gives MSE: 11455.337592269769
# Testing parameters {'param1': 53, 'param0': 43} gives MSE: 12548.20762549972
# Testing parameters {'param1': 61, 'param0': 43} gives MSE: 13054.06051049397
# Testing parameters {'param1': 3, 'param0': 47} gives MSE: 21449.61551554849
# Testing parameters {'param1': 5, 'param0': 47} gives MSE: 1313.9230104243168
# Testing parameters {'param1': 7, 'param0': 47} gives MSE: 120.6540872749603
# Testing parameters {'param1': 13, 'param0': 47} gives MSE: 4288.039122456983
# Testing parameters {'param1': 19, 'param0': 47} gives MSE: 7320.795367508947
# Testing parameters {'param1': 31, 'param0': 47} gives MSE: 10486.108244840743
# Testing parameters {'param1': 41, 'param0': 47} gives MSE: 11860.293190369308
# Testing parameters {'param1': 53, 'param0': 47} gives MSE: 12875.335261201424
# Testing parameters {'param1': 61, 'param0': 47} gives MSE: 13343.682200238647
# Testing parameters {'param1': 3, 'param0': 59} gives MSE: 8175.505394923622
# Testing parameters {'param1': 5, 'param0': 59} gives MSE: 6.890904651288315
# Testing parameters {'param1': 7, 'param0': 59} gives MSE: 1225.0497157846012
# Testing parameters {'param1': 13, 'param0': 59} gives MSE: 6148.920490036075
# Testing parameters {'param1': 19, 'param0': 59} gives MSE: 8913.212310569228
# Testing parameters {'param1': 31, 'param0': 59} gives MSE: 11626.18071840219
# Testing parameters {'param1': 41, 'param0': 59} gives MSE: 12770.20728275422
# Testing parameters {'param1': 53, 'param0': 59} gives MSE: 13605.243669868865
# Testing parameters {'param1': 61, 'param0': 59} gives MSE: 13987.992190486437
# Best parameters after search: {'param1': 7, 'param0': 43}
# Passed! Please submit.

# %% [markdown]
# **Fin.** If you have made it this far, congratulations on completing the exam. **Don't forget to submit!**
